-- %%
CREATE OR REPLACE TABLE ecommerce_analytics.data_warehouse.dim_customer (
  customer_id BIGINT,
  customer_name STRING

)

-- %%
INSERT INTO ecommerce_analytics.data_warehouse.dim_customer 
SELECT
customer_id,
customer_name

FROM batch_1.data.customers

-- %%
select*
from ecommerce_analytics.data_warehouse.dim_customer
