-- %%
CREATE OR REPLACE TABLE ecommerce_analytics.data_warehouse.fact_orders_item (
order_id as BIGINT,
customer_id BIGINT,
product_id STRING,
promo_id int,
order_date_key INT,
quantity INT,
price Double,
amount double
)

-- %%
INSERT INTO ecommerce_analytics.data_warehouse.fact_orders_item
SELECT
order_number as order_id,
customer_id,
product_id,
promo_id,
date_format(to_timestamp(order_datetime),'yyyyMMdd'),
---- order_date_key
qty as quantity,
price,
qty*price as amount

FROM batch_1.data.sales_orders

-- %%
Select* 
from ecommerce_analytics.data_warehouse.fact_orders_item
