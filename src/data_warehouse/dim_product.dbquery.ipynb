-- %%
create or replace table  ecommerce_analytics.data_warehouse.dim_product as
SELECT
DISTINCT
product_id,
product_name
FROM batch_1.data.sales_orders
WHERE product_id IS NOT NULL
select*
from ecommerce_analytics.data_warehouse.dim_product
